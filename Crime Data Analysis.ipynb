# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset using csv

# %%
df = pd.read_csv("../crime_ds.csv")

# %%
df.head() #display the top 5 row of datas
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892934 entries, 0 to 892933
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           892934 non-null  int64
#  1   Date Rptd       892934 non-null  object
#  2   DATE OCC        892934 non-null  object
#  3   TIME OCC        892934 non-null  int64
#  4   AREA            892934 non-null  int64
#  5   AREA NAME       892934 non-null  object
#  6   Rpt Dist No     892934 non-null  int64
#  7   Part 1-2        892934 non-null  int64
#  8   Crm Cd          892934 non-null  int64
#  9   Crm Cd Desc     892934 non-null  object
#  10  Mocodes         768605 non-null  object
#  11  Vict Age        892934 non-null  int64
#  12  Vict Sex        774633 non-null  object
#  13  Vict Descent    774625 non-null  object
#  14  Premis Cd       892924 non-null  float64
#  15  Premis Desc     892386 non-null  object
# ...

# %%
df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  8.929340e+05  892934.000000  892934.000000  892934.000000
# mean   2.175991e+08    1336.652506      10.700167    1116.451424
# std    1.158143e+07     653.157043       6.102301     610.234555
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.103178e+08     900.000000       6.000000     615.000000
# 50%    2.204101e+08    1415.000000      11.000000    1141.000000
# 75%    2.303115e+08    1900.000000      16.000000    1615.000000
# max    2.499046e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  892934.000000  892934.000000  892934.000000  892924.000000
# mean        1.411286     500.782104      29.642293     306.403196
# std         0.492067     207.633373      21.834910     217.283948
# min         1.000000     110.000000      -3.000000     101.000000
# ...

# %% [markdown]
# ## Histogram of crime occurrences over time

# %%
df['DATE OCC'] = pd.to_datetime(df['DATE OCC']) #Convert 'DATE OCC' to datetime type

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='DATE OCC', bins=50, kde=True)
plt.title('Distribution of Crime Occurrences Over Time')
plt.xlabel('Date of Occurrence')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# The above histogram shows the number of crimes reported on the y axis
# and the year  and month on which the crime was reported on the x axis
# It shows how the crimal activity was at its peak on June of 2022.

# %% [markdown]
# ## Time series plot of crime occurrences

# %%
df.set_index('DATE OCC', inplace=True)
df.resample('M').size().plot(legend=False)
plt.title('Monthly Crime Occurrences')
plt.xlabel('Year of Occurrence')
plt.ylabel('Number of Crimes')
plt.show()

# %%
df.head()
# Out:
#                 DR_NO               Date Rptd  TIME OCC  AREA  AREA NAME  \
# DATE OCC
# 2020-03-01  190326475  03/01/2020 12:00:00 AM      2130     7   Wilshire
# 2020-02-08  200106753  02/09/2020 12:00:00 AM      1800     1    Central
# 2020-11-04  200320258  11/11/2020 12:00:00 AM      1700     3  Southwest
# 2020-03-10  200907217  05/10/2023 12:00:00 AM      2037     9   Van Nuys
# 2020-08-17  220614831  08/18/2022 12:00:00 AM      1200     6  Hollywood
#
#             Rpt Dist No  Part 1-2  Crm Cd  \
# DATE OCC
# 2020-03-01          784         1     510
# 2020-02-08          182         1     330
# 2020-11-04          356         1     480
# 2020-03-10          964         1     343
# 2020-08-17          666         2     354
#
#                                          Crm Cd Desc              Mocodes  \
# DATE OCC
# 2020-03-01                          VEHICLE - STOLEN                  NaN
# 2020-02-08                     BURGLARY FROM VEHICLE       1822 1402 0344
# ...

# %%
# Reset the index, making 'DATE OCC' a regular column again
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#     DATE OCC      DR_NO               Date Rptd  TIME OCC  AREA  AREA NAME  \
# 0 2020-03-01  190326475  03/01/2020 12:00:00 AM      2130     7   Wilshire
# 1 2020-02-08  200106753  02/09/2020 12:00:00 AM      1800     1    Central
# 2 2020-11-04  200320258  11/11/2020 12:00:00 AM      1700     3  Southwest
# 3 2020-03-10  200907217  05/10/2023 12:00:00 AM      2037     9   Van Nuys
# 4 2020-08-17  220614831  08/18/2022 12:00:00 AM      1200     6  Hollywood
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          666         2     354                         THEFT OF IDENTITY
#
# ...

# %% [markdown]
# ## Bar Chart of Crime Type

# %%
top_crime_types = df['Crm Cd Desc'].value_counts().nlargest(40).index

plt.figure(figsize=(12,12))
sns.countplot(y='Crm Cd Desc', data=df, order=top_crime_types)
plt.title('Number of reported case')
plt.ylabel('Type of Crime')
plt.show()

# %% [markdown]
# As with the plotted bar chart we can see that Vehicle stolen is the most common crime. There are more than 200 different crimes
# but I just plotted top 40 crimes with most reporting. After vehicle stolen other crimes like Battery and theft of identity
# takes second and third place.
